# %%
import pandas as pd
import gzip
import json

file_path = "C:/Users/Shivangi Dubey/Downloads/users.json.gz" # Replace with the actual file path

# Create an empty DataFrame
df = pd.DataFrame()

# Open the gzipped file
with gzip.open(file_path, 'rb') as f:
    # Read the file content line by line
    for line in f:
        # Decode the line as UTF-8 and remove leading/trailing whitespaces
        decoded_line = line.decode('utf-8').strip()
        
        # Skip empty lines
        if not decoded_line:
            continue
        
        # Load the JSON data from the line
        json_data = json.loads(decoded_line)
        
        # Append the JSON data as a row to the DataFrame
        df = df.append(json_data, ignore_index=True)

# Print the DataFrame
print(df)

print(df.dtypes)

print(df.isnull().sum())

# Check for outliers in numerical columns
print(df.describe())
# Out:
# C:\Users\Shivangi Dubey\AppData\Local\Temp\ipykernel_21696\1106500209.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(json_data, ignore_index=True)
# C:\Users\Shivangi Dubey\AppData\Local\Temp\ipykernel_21696\1106500209.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(json_data, ignore_index=True)
# C:\Users\Shivangi Dubey\AppData\Local\Temp\ipykernel_21696\1106500209.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(json_data, ignore_index=True)
# C:\Users\Shivangi Dubey\AppData\Local\Temp\ipykernel_21696\1106500209.py:25: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
# ...

# %%
df['createdDate'] = df['createdDate'].apply(lambda x: pd.to_datetime(x['$date'], unit='ms'))

# %%
df['lastLogin'] = df['lastLogin'].apply(lambda x: pd.to_datetime(x['$date'], unit='ms') if isinstance(x, dict) else pd.NaT)

# %%
df['_id'] = df['_id'].apply(lambda x: x['$oid'] if isinstance(x, dict) else x)

# %%
df
# Out:
#                           _id  active             createdDate  \
# 0    5ff1e194b6a9d73a3a9f1052    True 2021-01-03 15:24:04.800
# 1    5ff1e194b6a9d73a3a9f1052    True 2021-01-03 15:24:04.800
# 2    5ff1e194b6a9d73a3a9f1052    True 2021-01-03 15:24:04.800
# 3    5ff1e1eacfcf6c399c274ae6    True 2021-01-03 15:25:30.554
# 4    5ff1e194b6a9d73a3a9f1052    True 2021-01-03 15:24:04.800
# ..                        ...     ...                     ...
# 490  54943462e4b07e684157a532    True 2014-12-19 14:21:22.381
# 491  54943462e4b07e684157a532    True 2014-12-19 14:21:22.381
# 492  54943462e4b07e684157a532    True 2014-12-19 14:21:22.381
# 493  54943462e4b07e684157a532    True 2014-12-19 14:21:22.381
# 494  54943462e4b07e684157a532    True 2014-12-19 14:21:22.381
#
#                   lastLogin         role signUpSource state
# 0   2021-01-03 15:25:37.858     consumer        Email    WI
# 1   2021-01-03 15:25:37.858     consumer        Email    WI
# ...
